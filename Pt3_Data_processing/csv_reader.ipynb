# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

sns.set(font_scale=1.5)

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
df = pd.read_csv('mainset.csv')
df.head()
# Out:
#    Unnamed: 0 nba_game_date  nba_season_id br_location nba_gm_type br_outcome  \
# 0           0    1999-11-02          21999        AWAY     Regular          W
# 1           1    1999-11-02          21999        AWAY     Regular          W
# 2           2    1999-11-02          21999        AWAY     Regular          W
# 3           3    1999-11-02          21999        HOME     Regular          L
# 4           4    1999-11-02          21999        HOME     Regular          L
#
#    home_plus_minus  nba_game_id  nba_team_id nba_team_abbreviation  ...  \
# 0              -20     29900013   1610612757                   POR  ...
# 1               -7     29900002   1610612754                   IND  ...
# 2               -7     29900011   1610612747                   LAL  ...
# 3              -13     29900006   1610612761                   TOR  ...
# 4              -13     29900006   1610612761                   TOR  ...
#
# ...

# %%
df.nba_pts
# Out:
# 0         7.0
# 1         6.0
# 2         3.0
# 3         7.0
# 4         8.0
#          ...
# 514699    4.0
# 514700    2.0
# 514701    1.0
# 514702    2.0
# 514703    0.0
# Name: nba_pts, Length: 514704, dtype: float64

# %%
xf = pd.read_csv('mainset2.csv')
xf.head()
# Out:
#          date  season_id location     type outcome  difference   game_id  \
# 0  1999-11-02      21999     AWAY  Regular       W         -20  29900013
# 1  1999-11-02      21999     AWAY  Regular       W          -7  29900002
# 2  1999-11-02      21999     AWAY  Regular       W          -7  29900011
# 3  1999-11-02      21999     HOME  Regular       L         -13  29900006
# 4  1999-11-02      21999     HOME  Regular       L         -13  29900006
#
#       team_id team_abb    team_city  ...  ast_pct ast_tov ast_ratio oreb_pct  \
# 0  1610612757      POR     Portland  ...    0.381     8.0      61.5      NaN
# 1  1610612754      IND      Indiana  ...    0.167     NaN      18.2      NaN
# 2  1610612747      LAL  Los Angeles  ...    0.143     1.0      14.3      NaN
# 3  1610612761      TOR      Toronto  ...    0.222     NaN      20.0      NaN
# 4  1610612761      TOR      Toronto  ...    0.125     1.0      14.3    0.038
#
# ...

# %%
xf.pts
# Out:
# 0         7.0
# 1         6.0
# 2         3.0
# 3         7.0
# 4         8.0
#          ...
# 514699    4.0
# 514700    2.0
# 514701    1.0
# 514702    2.0
# 514703    0.0
# Name: pts, Length: 514704, dtype: float64
