# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

sns.set(font_scale=1.5)

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
df = pd.read_csv('mainset2.csv')

variables = []
for col in df.columns:
    if 'id' in col:
        df[col] = df[col].astype('category')

for col in df.columns:
    if df[col].dtype == float or df[col].dtype == int:
        if 'difference' not in col:
            variables.append(col)
print('Numerical features :\n', variables)        
df.info()
# Out:
# Numerical features :
#  ['height', 'seconds', 'fgm', 'fga', 'fg3m', 'fg3a', 'ftm', 'fta', 'oreb', 'dreb', 'reb', 'ast', 'stl', 'blk', 'to', 'pf', 'pts', 'poss', 'off_rate', 'def_rate', 'net_rate', 'pace', 'ast_pct', 'ast_tov', 'ast_ratio', 'oreb_pct', 'dreb_pct', 'reb_pct', 'tm_tov_pct', 'usg_pct', 'game_score', 'plus_minus']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 514704 entries, 0 to 514703
# Data columns (total 46 columns):
# date              514704 non-null object
# season_id         514704 non-null category
# location          514704 non-null object
# type              514704 non-null object
# outcome           514704 non-null object
# difference        514704 non-null int64
# game_id           514704 non-null category
# team_id           514704 non-null category
# team_abb          514704 non-null object
# team_city         514704 non-null object
# player_id         514704 non-null category
# name              514704 non-null object
# start_position    269063 non-null object
# age_days          514704 non-null object
# height            514704 non-null float64
# seconds           514704 non-null int64
# fgm               514704 non-null float64
# fga               514704 non-null float64
# fg3m              514704 non-null float64
# fg3a              514704 non-null float64
# ftm               514704 non-null float64
# fta               514704 non-null float64
# oreb              514704 non-null float64
# dreb              514704 non-null float64
# reb               514704 non-null float64
# ast               514704 non-null float64
# stl               514704 non-null float64
# blk               514704 non-null float64
# to                514704 non-null float64
# pf                514704 non-null float64
# pts               514704 non-null float64
# poss              514704 non-null float64
# off_rate          514704 non-null float64
# def_rate          514704 non-null float64
# net_rate          514704 non-null float64
# pace              514704 non-null float64
# ast_pct           378501 non-null float64
# ast_tov           281861 non-null float64
# ast_ratio         378501 non-null float64
# oreb_pct          290087 non-null float64
# dreb_pct          454944 non-null float64
# reb_pct           475968 non-null float64
# tm_tov_pct        514704 non-null float64
# usg_pct           514704 non-null float64
# game_score        514704 non-null float64
# plus_minus        514704 non-null float64
# dtypes: category(4), float64(31), int64(2), object(9)
# memory usage: 169.4+ MB

# %%
# for col in df:
#     try:
#         print(f'{col} :   \t {len(df[df[col]==0])}')
#     except:
#         print(f'{col}\t: ERROR')

# %%
column_check = ['pct', 'date', 'id', 'pace', 'rating', 'height',
               'tov', 'ratio', 'pie', 'score']

columns_to_adj = []

for col in df.columns:
    if df[col].dtype ==(float or int):
        
        if any(ext in col for ext in column_check):
            print(f'To be ignored for minute adjustment\t: {col}')
        else:
            columns_to_adj.append(col)
    else:
        print(f'Team/Player Data\t\t\t: {col}')
              
columns_to_adj
# Out:
# Team/Player Data			: date
# Team/Player Data			: season_id
# Team/Player Data			: location
# Team/Player Data			: type
# Team/Player Data			: outcome
# Team/Player Data			: difference
# Team/Player Data			: game_id
# Team/Player Data			: team_id
# Team/Player Data			: team_abb
# Team/Player Data			: team_city
# Team/Player Data			: player_id
# Team/Player Data			: name
# Team/Player Data			: start_position
# Team/Player Data			: age_days
# To be ignored for minute adjustment	: height
# Team/Player Data			: seconds
# To be ignored for minute adjustment	: pace
# To be ignored for minute adjustment	: ast_pct
# To be ignored for minute adjustment	: ast_tov
# To be ignored for minute adjustment	: ast_ratio
# To be ignored for minute adjustment	: oreb_pct
# To be ignored for minute adjustment	: dreb_pct
# To be ignored for minute adjustment	: reb_pct
# To be ignored for minute adjustment	: tm_tov_pct
# To be ignored for minute adjustment	: usg_pct
# To be ignored for minute adjustment	: game_score
# ['fgm',
#  'fga',
#  'fg3m',
#  'fg3a',
#  'ftm',
#  'fta',
#  'oreb',
#  'dreb',
#  'reb',
#  'ast',
#  'stl',
#  'blk',
#  'to',
#  'pf',
#  'pts',
#  'poss',
#  'off_rate',
#  'def_rate',
#  'net_rate',
#  'plus_minus']

# %% [markdown]
# ### Non-adjusted time data

# %%
display(df.describe().T)
df_corr = df.loc[:,'seconds':].corr()
fig, ax = plt.subplots(figsize=(24, 20))
# mask
mask = np.triu(np.ones_like(df_corr, dtype=np.bool))
# adjust mask and df
mask = mask[1:, :-1]
corr = df_corr.iloc[1:,:-1].copy()
# color map
cmap = sns.diverging_palette(200, 10, 50, n=9, as_cmap=True)
# plot heatmap
sns.heatmap(corr, mask=mask, cmap=cmap, vmin=-1, vmax=1)
# ticks
yticks = [i.upper() for i in corr.index]
xticks = [i.upper() for i in corr.columns]
plt.yticks(plt.yticks()[0], labels=yticks, rotation=0)
plt.xticks(plt.xticks()[0], labels=xticks)
# title
title = 'CORRELATION MATRIX\nNBA BOX SCORES\n'
plt.title(title, loc='left', fontsize=18)
plt.show()
# Out:
#                count         mean         std       min        25%        50%  \
# difference  514704.0     3.322960   13.585443  -58.0000    -6.0000     4.0000
# height      514704.0     2.004497    0.090919    1.6002     1.9304     2.0066
# seconds     514704.0  1506.540330  621.222666  301.0000  1021.0000  1513.0000
# fgm         514704.0     3.880628    3.023453    0.0000     2.0000     3.0000
# fga         514704.0     8.562840    5.618131    0.0000     4.0000     8.0000
# fg3m        514704.0     0.745899    1.189406    0.0000     0.0000     0.0000
# fg3a        514704.0     2.091095    2.476602    0.0000     0.0000     1.0000
# ftm         514704.0     1.904302    2.434191    0.0000     0.0000     1.0000
# fta         514704.0     2.512003    2.987875    0.0000     0.0000     2.0000
# oreb        514704.0     1.153554    1.464058    0.0000     0.0000     1.0000
# dreb        514704.0     3.260322    2.697912    0.0000     1.0000     3.0000
# reb         514704.0     4.413877    3.519896    0.0000     2.0000     4.0000
# ast         514704.0     2.276625    2.534074    0.0000     0.0000     2.0000
# stl         514704.0     0.788587    1.006907    0.0000     0.0000     0.0000
# blk         514704.0     0.510190    0.919332    0.0000     0.0000     0.0000
# to          514704.0     1.432765    1.422734    0.0000     0.0000     1.0000
# pf          514704.0     2.188028    1.490210    0.0000     1.0000     2.0000
# pts         514704.0    10.411458    8.011075    0.0000     4.0000     9.0000
# poss        514704.0    49.733342   20.430683    7.0000    34.0000    50.0000
# off_rate    514704.0   102.662361   18.492893    0.0000    91.6000   103.1000
# def_rate    514704.0   104.092671   18.269365    0.0000    92.6000   103.7000
# net_rate    514704.0    -1.430272   25.769836 -176.5000   -16.6000    -0.6000
# pace        514704.0    95.662365    7.206232   56.7600    90.7900    95.3300
# ast_pct     378501.0     0.188154    0.126838    0.0230     0.0910     0.1540
# ast_tov     281861.0     1.927436    1.724129    0.0900     1.0000     1.3300
# ast_ratio   378501.0    21.373999   13.252799    2.0000    11.8000    18.5000
# oreb_pct    290087.0     0.083052    0.056947    0.0130     0.0420     0.0670
# dreb_pct    454944.0     0.147699    0.088095    0.0150     0.0830     0.1300
# reb_pct     475968.0     0.095710    0.057536    0.0080     0.0520     0.0830
# tm_tov_pct  514704.0    11.284780   12.263072    0.0000     0.0000     9.1000
# usg_pct     514704.0     0.186955    0.074566    0.0000     0.1350     0.1840
# game_score  514704.0     7.941416    7.169356  -11.7000     2.5000     6.7000
# plus_minus  514704.0     0.090289   10.849419  -57.0000    -7.0000     0.0000
#
#                   75%        max
# difference    12.0000    61.0000
# height         2.0828     2.3114
# seconds     2003.0000  3898.0000
# fgm            6.0000    28.0000
# fga           12.0000    50.0000
# fg3m           1.0000    14.0000
# fg3a           3.0000    24.0000
# ftm            3.0000    26.0000
# fta            4.0000    39.0000
# oreb           2.0000    18.0000
# dreb           5.0000    25.0000
# reb            6.0000    31.0000
# ast            3.0000    25.0000
# stl            1.0000    10.0000
# blk            1.0000    12.0000
# to             2.0000    14.0000
# pf             3.0000     7.0000
# pts           15.0000    81.0000
# poss          66.0000   122.0000
# off_rate     114.4000   237.6000
# def_rate     115.1000   237.5000
# net_rate      14.9000   173.7000
# pace         100.2100   162.7800
# ast_pct        0.2500     1.0000
# ast_tov        2.5000    21.0000
# ast_ratio     27.8000   100.0000
# oreb_pct       0.1110     1.0000
# dreb_pct       0.2000     1.0000
# reb_pct        0.1280     0.8330
# tm_tov_pct    16.7000   100.0000
# usg_pct        0.2350     0.6430
# game_score    12.1000    63.5000
# plus_minus     7.0000    57.0000

# %% [markdown]
# ### Adjusted data by per 40 min basis

# %%
for col in columns_to_adj:
    df[col] = df[col] / (df.seconds / 60) * 40

display(df.describe().T)

df_corr = df.loc[:,'seconds':].corr()
fig, ax = plt.subplots(figsize=(24, 20))
# mask
mask = np.triu(np.ones_like(df_corr, dtype=np.bool))
# adjust mask and df
mask = mask[1:, :-1]
corr = df_corr.iloc[1:,:-1].copy()
# color map
cmap = sns.diverging_palette(200, 10, 50, n=9, as_cmap=True)
# plot heatmap
sns.heatmap(corr, mask=mask, cmap=cmap, vmin=-1, vmax=1)
# ticks
yticks = [i.upper() for i in corr.index]
xticks = [i.upper() for i in corr.columns]
plt.yticks(plt.yticks()[0], labels=yticks, rotation=0)
plt.xticks(plt.xticks()[0], labels=xticks)
# title
title = 'CORRELATION MATRIX\nNBA BOX SCORES\n'
plt.title(title, loc='left', fontsize=18)
plt.show()
# Out:
#                count         mean         std          min          25%  \
# difference  514704.0     3.322960   13.585443   -58.000000    -6.000000
# height      514704.0     2.004497    0.090919     1.600200     1.930400
# seconds     514704.0  1506.540330  621.222666   301.000000  1021.000000
# fgm         514704.0     5.770725    3.613880     0.000000     3.225806
# fga         514704.0    13.061560    5.832739     0.000000     9.012876
# fg3m        514704.0     1.100637    1.743752     0.000000     0.000000
# fg3a        514704.0     3.202257    3.578302     0.000000     0.000000
# ftm         514704.0     2.759162    3.316449     0.000000     0.000000
# fta         514704.0     3.707767    4.157413     0.000000     0.000000
# oreb        514704.0     1.902260    2.475454     0.000000     0.000000
# dreb        514704.0     5.142966    3.789163     0.000000     2.416918
# reb         514704.0     7.045225    4.945002     0.000000     3.456553
# ast         514704.0     3.389316    3.394835     0.000000     0.000000
# stl         514704.0     1.231696    1.630907     0.000000     0.000000
# blk         514704.0     0.829960    1.557550     0.000000     0.000000
# to          514704.0     2.284287    2.276957     0.000000     0.000000
# pf          514704.0     3.869902    3.175576     0.000000     1.788376
# pts         514704.0    15.401248    9.115200     0.000000     8.980355
# poss        514704.0    79.523874    6.160440    49.357326    75.359234
# off_rate    514704.0   206.500064  136.519169     0.000000   123.675889
# def_rate    514704.0   215.150457  155.965600     0.000000   121.580647
# net_rate    514704.0    -8.650112   89.800020 -1366.644518   -27.591960
# pace        514704.0    95.662365    7.206232    56.760000    90.790000
# ast_pct     378501.0     0.188154    0.126838     0.023000     0.091000
# ast_tov     281861.0     1.927436    1.724129     0.090000     1.000000
# ast_ratio   378501.0    21.373999   13.252799     2.000000    11.800000
# oreb_pct    290087.0     0.083052    0.056947     0.013000     0.042000
# dreb_pct    454944.0     0.147699    0.088095     0.015000     0.083000
# reb_pct     475968.0     0.095710    0.057536     0.008000     0.052000
# tm_tov_pct  514704.0    11.284780   12.263072     0.000000     0.000000
# usg_pct     514704.0     0.186955    0.074566     0.000000     0.135000
# game_score  514704.0     7.941416    7.169356   -11.700000     2.500000
# plus_minus  514704.0    -1.230788   20.548260  -158.990536   -13.043478
#
#                     50%          75%          max
# difference     4.000000    12.000000    61.000000
# height         2.006600     2.082800     2.311400
# seconds     1513.000000  2003.000000  3898.000000
# fgm            5.565217     8.026756    46.905537
# fga           12.834225    16.794962    52.602740
# fg3m           0.000000     1.889764    26.086957
# fg3a           2.274882     5.408451    39.215686
# ftm            1.883091     4.465116    51.376147
# fta            2.807018     5.925926    67.226891
# oreb           1.176471     2.965404    40.776699
# dreb           4.580153     7.243461    42.105263
# reb            6.185567     9.822647    50.130548
# ast            2.631579     5.088339    35.467980
# stl            0.000000     2.056555    29.850746
# blk            0.000000     1.277955    30.573248
# to             1.933145     3.483309    29.538462
# pf             3.337969     5.293339    44.444444
# pts           14.814815    21.176471   117.263844
# poss          79.175258    83.333333   136.277603
# off_rate     162.670537   234.967945  1619.801980
# def_rate     162.334383   243.535273  1854.039735
# net_rate      -0.877153    22.527971  1286.666667
# pace          95.330000   100.210000   162.780000
# ast_pct        0.154000     0.250000     1.000000
# ast_tov        1.330000     2.500000    21.000000
# ast_ratio     18.500000    27.800000   100.000000
# oreb_pct       0.067000     0.111000     1.000000
# dreb_pct       0.130000     0.200000     1.000000
# reb_pct        0.083000     0.128000     0.833000
# tm_tov_pct     9.100000    16.700000   100.000000
# usg_pct        0.184000     0.235000     0.643000
# game_score     6.700000    12.100000    63.500000
# plus_minus     0.000000    11.526147   125.925926

# %%
import pickle
file = open("br_glossary.pickle",'rb')
br_glossary = pickle.load(file)
{s:br_glossary[s] for s in ['AST%','BLK%', 'eFG%','ORB%','DRB%','GmSc','Pace']}
# Out:
# {'AST%': 'Assist Percentage (available since the 1964-65 season in the NBA); the  formula is 100 * AST / (((MP / (Tm MP / 5)) * Tm FG) - FG).  Assist percentage is an estimate of the percentage of teammate field goals  a player assisted while he was on the floor.',
#  'BLK%': 'Block Percentage (available since the 1973-74 season in the NBA); the  formula is 100 * (BLK * (Tm MP / 5)) / (MP * (Opp FGA - Opp3PA)).  Block percentage is an estimate of the  percentage of opponent two-point field goal attempts blocked by the player  while he was on the floor.',
#  'eFG%': 'Effective Field Goal Percentage; the formula is (FG +  0.5 * 3P) / FGA.  This statistic  adjusts for the fact that a 3-point field goal is worth one more point  than a 2-point field goal. For example, suppose Player A goes 4 for 10  with 2 threes, while Player B goes 5 for 10 with 0 threes. Each player  would have 10 points from field goals, and thus would have the same  effective field goal percentage (50%).',
#  'ORB%': 'Offensive Rebound Percentage (available since the 1970-71 season in the  NBA); the formula is 100 * (ORB * (Tm MP / 5)) / (MP  * (Tm ORB + Opp DRB)).  Offensive rebound  percentage is an estimate of the percentage of available offensive  rebounds a player grabbed while he was on the floor.',
#  'DRB%': 'Defensive Rebound Percentage (available since the 1970-71 season in the  NBA); the formula is 100 * (DRB * (Tm MP / 5)) / (MP  * (Tm DRB + Opp ORB)).  Defensive rebound  percentage is an estimate of the percentage of available defensive  rebounds a player grabbed while he was on the floor.',
#  'GmSc': "Game Score; the formula is PTS + 0.4 * FG - 0.7 * FGA - 0.4*(FTA - FT) + 0.7 * ORB  + 0.3 * DRB + STL + 0.7 * AST + 0.7 * BLK - 0.4 * PF - TOV.  Game Score was created by  John Hollinger to give a rough measure of a player's productivity  for a single  game.  The scale is similar to that of points scored, (40 is  an outstanding performance, 10 is an average performance, etc.).",
#  'Pace': 'Pace Factor (available since the 1973-74 season in the NBA); the formula  is 48 * ((Tm Poss + Opp Poss) / (2 * (Tm MP / 5))).  Pace factor is an  estimate of the number of possessions per 48 minutes by a team. (Note: 40 minutes is used in the calculation for the  WN'}

# %%
df.sort_values(by='date', inplace=True)
print(df[df.player_id==2544].name.unique())
test = df.groupby(
    'player_id').get_group(2544)

test.set_index("date", inplace=True)
test_ewm = test[variables]

test_ewm.columns = ['{}_{}'.format('ewm', col) for col in test_ewm.columns]

all_columns = list(df.columns) + list(test_ewm.columns)

print('TEST :\n')
display(test_ewm.ewm(span=12, min_periods=1).mean().shift().fillna(0))
# Out:
# ['LeBron James']
# TEST :
#             ewm_height  ewm_seconds    ewm_fgm    ewm_fga  ewm_fg3m  ewm_fg3a  \
# date
# 2003-10-29      0.0000     0.000000   0.000000   0.000000  0.000000  0.000000
# 2003-10-30      2.0574  2570.000000  11.206226  18.677043  0.000000  1.867704
# 2003-11-01      2.0574  2489.291667   9.431932  17.688771  0.536968  3.540872
# 2003-11-05      2.0574  2434.926097   6.946460  15.568093  0.327389  2.557473
# 2003-11-07      2.0574  2444.734914   5.675372  14.033193  0.224045  2.364604
# ...                ...          ...        ...        ...       ...       ...
# 2020-10-02      2.0574  2150.308108  11.177197  20.971361  1.978201  5.707488
# 2020-10-04      2.0574  2180.876091  11.658237  21.674657  2.145421  6.086904
# 2020-10-06      2.0574  2207.356692  11.276934  20.850801  1.972276  5.935053
# 2020-10-09      2.0574  2224.532586  10.815780  20.190503  1.987288  5.818067
# 2020-10-11      2.0574  2268.604496  11.357493  20.172223  2.563824  6.246387
#
#              ewm_ftm   ewm_fta  ewm_oreb   ewm_dreb  ...  ewm_ast_pct  \
# date                                                 ...
# 2003-10-29  0.000000  0.000000  0.000000   0.000000  ...     0.000000
# 2003-10-30  0.933852  2.801556  1.867704   3.735409  ...     0.360000
# 2003-11-01  2.575888  5.042824  1.929968   7.081744  ...     0.331833
# 2003-11-05  2.367728  3.871818  1.176701   5.912156  ...     0.292478
# 2003-11-07  1.927541  2.956849  1.419687   6.810832  ...     0.281910
# ...              ...       ...       ...        ...  ...          ...
# 2020-10-02  5.975123  7.757067  1.433126  10.624461  ...     0.434906
# 2020-10-04  5.370246  7.349604  1.527018  10.090233  ...     0.425690
# 2020-10-06  5.485569  7.631168  1.449011   9.950162  ...     0.432661
# 2020-10-09  6.233834  8.367780  1.544526  10.011566  ...     0.430867
# 2020-10-11  5.862964  7.962701  1.748043   9.941778  ...     0.415810
#
#             ewm_ast_tov  ewm_ast_ratio  ewm_oreb_pct  ewm_dreb_pct  \
# date
# 2003-10-29     0.000000       0.000000      0.000000      0.000000
# 2003-10-30     4.500000      28.100000      0.050000      0.091000
# 2003-11-01     2.680000      25.283333      0.048917      0.157083
# 2003-11-05     2.804896      26.577829      0.048917      0.140268
# 2003-11-07     3.024313      29.236379      0.045507      0.155335
# ...                 ...            ...           ...           ...
# 2020-10-02     3.004985      25.932025      0.046572      0.266371
# 2020-10-04     3.004985      25.896329      0.046127      0.263853
# 2020-10-06     2.612717      25.435355      0.042709      0.262798
# 2020-10-09     2.371828      25.045300      0.045432      0.265137
# 2020-10-11     2.258885      24.361408      0.051299      0.262808
#
#             ewm_reb_pct  ewm_tm_tov_pct  ewm_usg_pct  ewm_game_score  \
# date
# 2003-10-29     0.000000        0.000000     0.000000        0.000000
# 2003-10-30     0.071000        6.300000     0.247000       24.700000
# 2003-11-01     0.105667       13.720833     0.268667       19.283333
# 2003-11-05     0.087062       12.073441     0.234450       13.708545
# 2003-11-07     0.095250       11.418937     0.201164       12.916695
# ...                 ...             ...          ...             ...
# 2020-10-02     0.157812        9.927486     0.299942       24.735085
# 2020-10-04     0.152456        8.400181     0.298258       25.637380
# 2020-10-06     0.149771       10.630922     0.298526       24.431629
# 2020-10-09     0.153037       11.626165     0.301984       24.272917
# 2020-10-11     0.155492       11.652909     0.299217       26.554007
#
#             ewm_plus_minus
# date
# 2003-10-29        0.000000
# 2003-10-30       -8.404669
# 2003-11-01       -5.463045
# 2003-11-05      -11.701511
# 2003-11-07       -8.929439
# ...                    ...
# 2020-10-02        8.729710
# 2020-10-04        8.486983
# 2020-10-06        6.553616
# 2020-10-09        5.226928
# 2020-10-11        5.452102
#
# [1525 rows x 32 columns]

# %%
all_ewm_dfs = []
for player in df['player_id'].unique():
    a_box = np.array(
        df[df['player_id']==player])
    b_box = np.array(
        df[df['player_id']==player][variables].ewm(
            span=16, min_periods=2).mean().shift())
    ab_box = np.concatenate([a_box, b_box], axis=1)
    all_ewm_dfs.append(ab_box)

concat_array = np.concatenate(all_ewm_dfs, axis=0)

ewm_data = pd.DataFrame(concat_array, columns=all_columns)
a_box = []
b_box = []
all_ewm_dfs = []
concat_array = []
print(ewm_data.shape)
ewm_data.columns
# Out:
# (514704, 78)
# Index(['date', 'season_id', 'location', 'type', 'outcome', 'difference',
#        'game_id', 'team_id', 'team_abb', 'team_city', 'player_id', 'name',
#        'start_position', 'age_days', 'height', 'seconds', 'fgm', 'fga', 'fg3m',
#        'fg3a', 'ftm', 'fta', 'oreb', 'dreb', 'reb', 'ast', 'stl', 'blk', 'to',
#        'pf', 'pts', 'poss', 'off_rate', 'def_rate', 'net_rate', 'pace',
#        'ast_pct', 'ast_tov', 'ast_ratio', 'oreb_pct', 'dreb_pct', 'reb_pct',
#        'tm_tov_pct', 'usg_pct', 'game_score', 'plus_minus', 'ewm_height',
#        'ewm_seconds', 'ewm_fgm', 'ewm_fga', 'ewm_fg3m', 'ewm_fg3a', 'ewm_ftm',
#        'ewm_fta', 'ewm_oreb', 'ewm_dreb', 'ewm_reb', 'ewm_ast', 'ewm_stl',
#        'ewm_blk', 'ewm_to', 'ewm_pf', 'ewm_pts', 'ewm_poss', 'ewm_off_rate',
#        'ewm_def_rate', 'ewm_net_rate', 'ewm_pace', 'ewm_ast_pct',
#        'ewm_ast_tov', 'ewm_ast_ratio', 'ewm_oreb_pct', 'ewm_dreb_pct',
#        'ewm_reb_pct', 'ewm_tm_tov_pct', 'ewm_usg_pct', 'ewm_game_score',
#        'ewm_plus_minus'],
#       dtype='object')

# %%
ewm_data.date =pd.to_datetime(ewm_data.date)
for col in ewm_data.loc[:,'height':]:
    ewm_data[col] = ewm_data[col].apply(lambda x: float(x))

# %%
plt.figure(figsize=(20,9))
sns.lineplot(data = ewm_data[(ewm_data['team_abb']=='TOR')&
                             (ewm_data['date']>'2018-09-01')&
                             ((ewm_data['date']<'2019-09-01'))],
             x='date',y='ewm_seconds', err_style='bars', hue='name',
            legend=False);
# Out:
# /Users/finnalexander/Desktop/Anaconda/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(20,9))
sns.lineplot(data = ewm_data[(ewm_data['name']=='James Harden')&
                            (ewm_data['date']>'2018-01-01')],
             x='date',y='ewm_pts', err_style='bars')

sns.lineplot(data = ewm_data[(ewm_data['name']=='James Harden')&
                            (ewm_data['date']>'2018-01-01')],
             x='date',y='pts', err_style='bars');

# %%
plt.figure(figsize=(20,9))
sns.lineplot(data = ewm_data[(ewm_data['name']=='Kawhi Leonard')&
                            (ewm_data['date']>'2018-01-01')],
             x='date',y='ewm_pts', err_style='bars')

sns.lineplot(data = ewm_data[(ewm_data['name']=='Kawhi Leonard')&
                            (ewm_data['date']>'2018-01-01')],
             x='date',y='pts', err_style='bars');

# %%
ewm_data['location'] = pd.get_dummies(ewm_data['location'], drop_first=True)['HOME']
ewm_data['outcome'] = pd.get_dummies(ewm_data['outcome'], drop_first=True)['W']
ewm_data['type'] = pd.get_dummies(ewm_data['type'], drop_first=True)['Regular']

# %%
non_shifted = ['seconds', 'fgm', 'fga', 'fg3m',
       'fg3a', 'ftm', 'fta', 'oreb', 'dreb', 'reb', 'ast', 'stl', 'blk', 'to',
       'pf', 'pts', 'poss', 'off_rate', 'def_rate', 'net_rate', 'pace',
       'ast_pct', 'ast_tov', 'ast_ratio', 'oreb_pct', 'dreb_pct', 'reb_pct',
       'tm_tov_pct', 'usg_pct', 'game_score', 'plus_minus', 'ewm_height']

ewm_data.drop(columns = non_shifted, inplace=True)

grouped_data = ewm_data.groupby(['game_id', 'team_id'])

# 20000011 ['1610612744', '1610612756']

t2 = grouped_data.get_group((20000011, 1610612744)).sort_values(by='ewm_seconds', ascending=False)
t3 = grouped_data.get_group((20000011, 1610612756)).sort_values(by='ewm_seconds', ascending=False)

t2[t2['start_position']=='G']
# Out:
#              date season_id  location  type  outcome difference   game_id  \
# 24409  2000-10-31     22000         1     1        1          2  20000011
# 112316 2000-10-31     22000         1     1        1          2  20000011
#
#            team_id team_abb     team_city  ... ewm_ast_pct ewm_ast_tov  \
# 24409   1610612744      GSW  Golden State  ...    0.198764    1.734582
# 112316  1610612744      GSW  Golden State  ...    0.299998    2.977760
#
#        ewm_ast_ratio ewm_oreb_pct  ewm_dreb_pct  ewm_reb_pct  ewm_tm_tov_pct  \
# 24409      13.535408     0.047537      0.123960     0.075611        8.972754
# 112316     27.090248     0.036723      0.134424     0.069111        7.382094
#
#         ewm_usg_pct  ewm_game_score  ewm_plus_minus
# 24409      0.286022       14.988113       -8.584581
# 112316     0.189012       10.690216      -10.632339
#
# [2 rows x 46 columns]

# %%
a = np.vstack((np.array(t2[t2['start_position']=='G'].sort_values(by='height', ascending=False)),
         np.array(t2[t2['start_position']=='F'].sort_values(by='height', ascending=False)),
          np.array(t2[t2['start_position']=='C']),
          np.array(t2[t2['start_position'].isin(
              ['G','F','C'])==False].sort_values(
              by='ewm_seconds', ascending=False).iloc[:3,:].sort_values(
          by='height')))).ravel()

b = np.vstack((np.array(t3[t3['start_position']=='G'].sort_values(by='height', ascending=False)),
         np.array(t3[t3['start_position']=='F'].sort_values(by='height', ascending=False)),
          np.array(t3[t3['start_position']=='C']),
          np.array(t3[t3['start_position'].isin(
              ['G','F','C'])==False].sort_values(
              by='ewm_seconds', ascending=False).iloc[:3,:].sort_values(
          by='height')))).ravel()

game_test_columns = np.array(
    [['{}_{}'.format(i, col) for col in t2.columns] for i in [
        'pg', 'sg', 'sf', 'pf', 'c_', 's1', 's2', 's3']]).ravel()

game_test = pd.DataFrame(np.vstack(
    (a,b)), columns=game_test_columns)

game_test.head()
game_test[[col for col in game_test if \
           any(n in col for n in ['height','start'])]]
# Out:
#   pg_start_position pg_height sg_start_position sg_height sf_start_position  \
# 0                 G    1.9558                 G    1.8288                 F
# 1                 G    1.9558                 G    1.9304                 F
#
#   sf_height pf_start_position pf_height c__start_position c__height  \
# 0    2.0574                 F     2.032                 C    2.1082
# 1    2.0828                 F    2.0066                 C    2.1082
#
#   s1_start_position s1_height s2_start_position s2_height s3_start_position  \
# 0               NaN     1.905               NaN    2.0066               NaN
# 1               NaN    1.8796               NaN    2.0066               NaN
#
#   s3_height
# 0    2.0828
# 1    2.0828

# %%
def team_ravel(df): 
    return np.vstack((np.array(df[df['start_position']=='G'].sort_values(by='height', ascending=False)),
         np.array(df[df['start_position']=='F'].sort_values(by='height', ascending=False)),
          np.array(df[df['start_position']=='C']),
          np.array(df[df['start_position'].isin(
              ['G','F','C'])==False].sort_values(
              by='ewm_seconds', ascending=False).iloc[:3,:].sort_values(
          by='height')))).ravel()

# %%
remove = ['date', 'season_id', 'location', 'type', 'outcome','difference',
          'game_id', 'team_id', 'team_abb','team_city','start_position']

necessary_drop = [col for col in game_test.loc[:,'pg_name':].columns if \
                  any(n in col for n in remove)]

game_test.drop(columns=necessary_drop, inplace=True)

end_game = np.array([['{}{}'.format(ha, col) for col in game_test.columns] \
                    for ha in ['h_','a_']]).ravel()

# %%
pd.DataFrame(np.vstack((np.array(game_test).ravel(),
              np.array(game_test).ravel())),
            columns=end_game)
# Out:
#    h_pg_date h_pg_season_id h_pg_location h_pg_type h_pg_outcome  \
# 0 2000-10-31          22000             1         1            1
# 1 2000-10-31          22000             1         1            1
#
#   h_pg_difference h_pg_game_id h_pg_team_id h_pg_team_abb h_pg_team_city  ...  \
# 0               2     20000011   1610612744           GSW   Golden State  ...
# 1               2     20000011   1610612744           GSW   Golden State  ...
#
#   a_s3_ewm_ast_pct a_s3_ewm_ast_tov a_s3_ewm_ast_ratio a_s3_ewm_oreb_pct  \
# 0         0.230195          1.21419            22.3745          0.170037
# 1         0.230195          1.21419            22.3745          0.170037
#
#   a_s3_ewm_dreb_pct a_s3_ewm_reb_pct a_s3_ewm_tm_tov_pct a_s3_ewm_usg_pct  \
# 0          0.189059          0.15909              21.383         0.132135
# 1          0.189059          0.15909              21.383         0.132135
#
#   a_s3_ewm_game_score a_s3_ewm_plus_minus
# 0             3.34631           -0.519917
# 1             3.34631           -0.519917
#
# [2 rows x 580 columns]

# %%
len(np.concatenate((team_ravel(t2), team_ravel(t3))))
# Out:
# 736

# %%
game_keys = {}
for gameid, teamid in grouped_data.groups.keys():
    game_keys[gameid] = []
for gameid, teamid in grouped_data.groups.keys():
    game_keys[gameid].append(teamid)

# %%
from tqdm import tqdm

all_rows = np.array([])
reversed_rows = np.array([])
c=0
e=0
errors = {}
for game in tqdm(list(game_keys.keys())):
    if game == 0:
        continue
    try:
        a = grouped_data.get_group((game, game_keys[game][0]))
        b = grouped_data.get_group((game, game_keys[game][1]))
        a = team_ravel(a)
        b = team_ravel(b)
        game_df = pd.DataFrame(np.vstack(
            (a,b)), columns=game_test_columns)
        c+=1
    except:
        errors[game] = game_keys[game]
        e+=1
#         print(f'Total errors: {e}')
    
    remove = ['date', 'season_id', 'location', 'type', 'outcome','difference',
          'game_id', 'team_id', 'team_abb','team_city','start_position']

    necessary_drop = [col for col in game_df.loc[:,'pg_name':].columns if \
                  any(n in col for n in remove)]
    
    game_df.drop(columns=necessary_drop, inplace=True)
    game_df.pg_location = game_df.pg_location.apply(lambda x: int(x))
    
    row = np.array(
        game_df.sort_values(by='pg_location',
                            ascending=False)).ravel()
    reversed_row = np.array(
        game_df.sort_values(by='pg_location')).ravel()
    
    try:
        if all_rows.size == 0:
            all_rows = np.vstack([row])
            reversed_rows = np.vstack([reversed_row])
        else:
            all_rows = np.vstack([all_rows, row])
            reversed_rows = np.vstack(
                [reversed_rows, reversed_row])
    except:
#         print('\n===ERROR!!!===\n', game, bi_keys[game], '\n===!!!!!!!!===\n')
        pass

structured_df = pd.DataFrame(all_rows,
                             columns=end_game)
reversed_df = pd.DataFrame(reversed_rows,
                           columns=end_game)
display(structured_df.head())
display(reversed_df.head())

print(f'TOTAL ERRORS  : {e}')
print(f'ERROR PERCENT : {(e/(e+c) * 100):0f}%')
# Out:
# 100%|██████████| 26936/26936 [2:02:17<00:00,  3.67it/s]
#    h_pg_date h_pg_season_id h_pg_location h_pg_type h_pg_outcome  \
# 0 2000-10-31          22000             1         1            0
# 1 2000-10-31          22000             1         1            0
# 2 2000-10-31          22000             1         1            1
# 3 2000-10-31          22000             1         1            0
# 4 2000-10-31          22000             1         1            0
#
#   h_pg_difference h_pg_game_id h_pg_team_id h_pg_team_abb h_pg_team_city  ...  \
# 0             -29     20000001   1610612752           NYK       New York  ...
# 1              -4     20000002   1610612751           NJN     New Jersey  ...
# 2              11     20000003   1610612753           ORL        Orlando  ...
# 3             -24     20000004   1610612737           ATL        Atlanta  ...
# 4              -9     20000005   1610612761           TOR        Toronto  ...
#
#   a_s3_ewm_ast_pct a_s3_ewm_ast_tov a_s3_ewm_ast_ratio a_s3_ewm_oreb_pct  \
# 0         0.191532          2.09617            18.4509         0.0515065
# 1         0.131081          1.20377            18.8863         0.0768267
# 2         0.126811          1.67841            18.6564         0.0871917
# 3         0.134293         0.842759            17.4981          0.084241
# 4         0.108868          1.17743            15.1877          0.130139
#
#   a_s3_ewm_dreb_pct a_s3_ewm_reb_pct a_s3_ewm_tm_tov_pct a_s3_ewm_usg_pct  \
# 0          0.126231        0.0706584             10.0968         0.206562
# 1          0.143634        0.0859414             16.1359         0.167021
# 2          0.191026         0.124839             8.76058         0.134936
# 3          0.148311          0.10035             18.4173         0.175481
# 4           0.23346         0.175061             14.9553         0.160079
#
#   a_s3_ewm_game_score a_s3_ewm_plus_minus
# 0             7.10821           -0.422827
# 1             3.23404           -0.632359
# 2             6.25537            -10.5871
# 3             1.86454            -9.18108
# 4             7.28209             7.25298
#
# [5 rows x 580 columns]
#    h_pg_date h_pg_season_id h_pg_location h_pg_type h_pg_outcome  \
# 0 2000-10-31          22000             0         1            1
# 1 2000-10-31          22000             0         1            1
# 2 2000-10-31          22000             0         1            0
# 3 2000-10-31          22000             0         1            1
# 4 2000-10-31          22000             0         1            1
#
#   h_pg_difference h_pg_game_id h_pg_team_id h_pg_team_abb h_pg_team_city  ...  \
# 0             -29     20000001   1610612755           PHI   Philadelphia  ...
# 1              -4     20000002   1610612739           CLE      Cleveland  ...
# 2              11     20000003   1610612764           WAS     Washington  ...
# 3             -24     20000004   1610612766           CHH      Charlotte  ...
# 4              -9     20000005   1610612765           DET        Detroit  ...
#
#   a_s3_ewm_ast_pct a_s3_ewm_ast_tov a_s3_ewm_ast_ratio a_s3_ewm_oreb_pct  \
# 0         0.102399          1.65153            14.5389         0.0422977
# 1         0.142184          1.21622            46.4261          0.133599
# 2        0.0989926         0.853744            13.3207         0.0622519
# 3         0.166727          1.10009            18.2387         0.0936853
# 4         0.085271          0.96702            10.3653         0.0865887
#
#   a_s3_ewm_dreb_pct a_s3_ewm_reb_pct a_s3_ewm_tm_tov_pct a_s3_ewm_usg_pct  \
# 0          0.104328        0.0567675             10.6523          0.17233
# 1          0.179532          0.13017             11.2086        0.0877655
# 2           0.12616        0.0737463             10.2021         0.173488
# 3          0.147511        0.0864749             11.8696         0.209338
# 4          0.202631         0.139005             9.74625         0.210793
#
#   a_s3_ewm_game_score a_s3_ewm_plus_minus
# 0             7.41214            -4.44846
# 1             3.12126            -10.2988
# 2             3.81113           -0.076545
# 3             3.66247            -10.6174
# 4             5.86323            -2.72683
#
# [5 rows x 580 columns]
# TOTAL ERRORS  : 1439
# ERROR PERCENT : 5.342293%

# %%
print(f'TOTAL ERRORS  : {e}')
print(f'ERROR PERCENT : {(e/(e+c) * 100):0f}%')
# Out:
# TOTAL ERRORS  : 1439
# ERROR PERCENT : 5.342293%

# %%
structured_df.shape, reversed_df.shape
# Out:
# ((26936, 580), (26936, 580))

# %%
non_shifted = ['seconds', 'fgm', 'fga', 'fg3m',
       'fg3a', 'ftm', 'fta', 'oreb', 'dreb', 'reb', 'ast', 'stl', 'blk', 'to',
       'pf', 'pts', 'poss', 'off_rate', 'def_rate', 'net_rate', 'pace',
       'ast_pct', 'ast_tov', 'ast_ratio', 'oreb_pct', 'dreb_pct', 'reb_pct',
       'tm_tov_pct', 'usg_pct', 'game_score', 'plus_minus', 'ewm_height']

columns_to_drop = [col for col in end_game if 'ewm' not in col \
 and any(c in col for c in non_shifted) and \
col not in ['h_pf_player_id','h_pf_name',
            'h_pf_age_days','h_pf_height']] + \
[col for col in end_game if 'ewm_height' in col]

# %%
structured_df.drop(columns=columns_to_drop, inplace=True)
reversed_df.drop(columns=columns_to_drop, inplace=True)

# %%
structured_df.to_csv('home_structured_ewm16.csv')
reversed_df.to_csv('away_structured_ewm16.csv')

# %%
structured_df.shape, reversed_df.shape
# Out:
# ((26936, 572), (26936, 572))

# %%
[col for col in columns_to_drop]
# Out:
# []

# %%
columns_to_drop
# Out:
# []

# %%
[col for col in end_game if 'ewm' not in col \
 and any(c in col for c in non_shifted) and \
col not in ['h_pf_player_id','h_pf_name',
            'h_pf_age_days','h_pf_height']] + \
[col for col in end_game if 'ewm_height' in col]
# Out:
# ['h_pg_seconds',
#  'h_pg_fgm',
#  'h_pg_fga',
#  'h_pg_fg3m',
#  'h_pg_fg3a',
#  'h_pg_ftm',
#  'h_pg_fta',
#  'h_pg_oreb',
#  'h_pg_dreb',
#  'h_pg_reb',
#  'h_pg_ast',
#  'h_pg_stl',
#  'h_pg_blk',
#  'h_pg_to',
#  'h_pg_pf',
#  'h_pg_pts',
#  'h_pg_poss',
#  'h_pg_off_rate',
#  'h_pg_def_rate',
#  'h_pg_net_rate',
#  'h_pg_pace',
#  'h_pg_ast_pct',
#  'h_pg_ast_tov',
#  'h_pg_ast_ratio',
#  'h_pg_oreb_pct',
#  'h_pg_dreb_pct',
#  'h_pg_reb_pct',
#  'h_pg_tm_tov_pct',
#  'h_pg_usg_pct',
#  'h_pg_game_score',
#  'h_pg_plus_minus',
#  'h_sg_seconds',
#  'h_sg_fgm',
#  'h_sg_fga',
#  'h_sg_fg3m',
#  'h_sg_fg3a',
#  'h_sg_ftm',
#  'h_sg_fta',
#  'h_sg_oreb',
#  'h_sg_dreb',
#  'h_sg_reb',
#  'h_sg_ast',
#  'h_sg_stl',
#  'h_sg_blk',
#  'h_sg_to',
#  'h_sg_pf',
#  'h_sg_pts',
#  'h_sg_poss',
#  'h_sg_off_rate',
#  'h_sg_def_rate',
#  'h_sg_net_rate',
#  'h_sg_pace',
#  'h_sg_ast_pct',
#  'h_sg_ast_tov',
#  'h_sg_ast_ratio',
#  'h_sg_oreb_pct',
#  'h_sg_dreb_pct',
#  'h_sg_reb_pct',
#  'h_sg_tm_tov_pct',
#  'h_sg_usg_pct',
#  'h_sg_game_score',
#  'h_sg_plus_minus',
#  'h_sf_seconds',
#  'h_sf_fgm',
#  'h_sf_fga',
#  'h_sf_fg3m',
#  'h_sf_fg3a',
#  'h_sf_ftm',
#  'h_sf_fta',
#  'h_sf_oreb',
#  'h_sf_dreb',
#  'h_sf_reb',
#  'h_sf_ast',
#  'h_sf_stl',
#  'h_sf_blk',
#  'h_sf_to',
#  'h_sf_pf',
#  'h_sf_pts',
#  'h_sf_poss',
#  'h_sf_off_rate',
#  'h_sf_def_rate',
#  'h_sf_net_rate',
#  'h_sf_pace',
#  'h_sf_ast_pct',
#  'h_sf_ast_tov',
#  'h_sf_ast_ratio',
#  'h_sf_oreb_pct',
#  'h_sf_dreb_pct',
#  'h_sf_reb_pct',
#  'h_sf_tm_tov_pct',
#  'h_sf_usg_pct',
#  'h_sf_game_score',
#  'h_sf_plus_minus',
#  'h_pf_seconds',
#  'h_pf_fgm',
#  'h_pf_fga',
#  'h_pf_fg3m',
#  'h_pf_fg3a',
#  'h_pf_ftm',
#  'h_pf_fta',
#  'h_pf_oreb',
#  'h_pf_dreb',
#  'h_pf_reb',
#  'h_pf_ast',
#  'h_pf_stl',
#  'h_pf_blk',
#  'h_pf_to',
#  'h_pf_pf',
#  'h_pf_pts',
#  'h_pf_poss',
#  'h_pf_off_rate',
#  'h_pf_def_rate',
#  'h_pf_net_rate',
#  'h_pf_pace',
#  'h_pf_ast_pct',
#  'h_pf_ast_tov',
#  'h_pf_ast_ratio',
#  'h_pf_oreb_pct',
#  'h_pf_dreb_pct',
#  'h_pf_reb_pct',
#  'h_pf_tm_tov_pct',
#  'h_pf_usg_pct',
#  'h_pf_game_score',
#  'h_pf_plus_minus',
#  'h_c__seconds',
#  'h_c__fgm',
#  'h_c__fga',
#  'h_c__fg3m',
#  'h_c__fg3a',
#  'h_c__ftm',
#  'h_c__fta',
#  'h_c__oreb',
#  'h_c__dreb',
#  'h_c__reb',
#  'h_c__ast',
#  'h_c__stl',
#  'h_c__blk',
#  'h_c__to',
#  'h_c__pf',
#  'h_c__pts',
#  'h_c__poss',
#  'h_c__off_rate',
#  'h_c__def_rate',
#  'h_c__net_rate',
#  'h_c__pace',
#  'h_c__ast_pct',
#  'h_c__ast_tov',
#  'h_c__ast_ratio',
#  'h_c__oreb_pct',
#  'h_c__dreb_pct',
#  'h_c__reb_pct',
#  'h_c__tm_tov_pct',
#  'h_c__usg_pct',
#  'h_c__game_score',
#  'h_c__plus_minus',
#  'h_s1_seconds',
#  'h_s1_fgm',
#  'h_s1_fga',
#  'h_s1_fg3m',
#  'h_s1_fg3a',
#  'h_s1_ftm',
#  'h_s1_fta',
#  'h_s1_oreb',
#  'h_s1_dreb',
#  'h_s1_reb',
#  'h_s1_ast',
#  'h_s1_stl',
#  'h_s1_blk',
#  'h_s1_to',
#  'h_s1_pf',
#  'h_s1_pts',
#  'h_s1_poss',
#  'h_s1_off_rate',
#  'h_s1_def_rate',
#  'h_s1_net_rate',
#  'h_s1_pace',
#  'h_s1_ast_pct',
#  'h_s1_ast_tov',
#  'h_s1_ast_ratio',
#  'h_s1_oreb_pct',
#  'h_s1_dreb_pct',
#  'h_s1_reb_pct',
#  'h_s1_tm_tov_pct',
#  'h_s1_usg_pct',
#  'h_s1_game_score',
#  'h_s1_plus_minus',
#  'h_s2_seconds',
#  'h_s2_fgm',
#  'h_s2_fga',
#  'h_s2_fg3m',
#  'h_s2_fg3a',
#  'h_s2_ftm',
#  'h_s2_fta',
#  'h_s2_oreb',
#  'h_s2_dreb',
#  'h_s2_reb',
#  'h_s2_ast',
#  'h_s2_stl',
#  'h_s2_blk',
#  'h_s2_to',
#  'h_s2_pf',
#  'h_s2_pts',
#  'h_s2_poss',
#  'h_s2_off_rate',
#  'h_s2_def_rate',
#  'h_s2_net_rate',
#  'h_s2_pace',
#  'h_s2_ast_pct',
#  'h_s2_ast_tov',
#  'h_s2_ast_ratio',
#  'h_s2_oreb_pct',
#  'h_s2_dreb_pct',
#  'h_s2_reb_pct',
#  'h_s2_tm_tov_pct',
#  'h_s2_usg_pct',
#  'h_s2_game_score',
#  'h_s2_plus_minus',
#  'h_s3_seconds',
#  'h_s3_fgm',
#  'h_s3_fga',
#  'h_s3_fg3m',
#  'h_s3_fg3a',
#  'h_s3_ftm',
#  'h_s3_fta',
#  'h_s3_oreb',
#  'h_s3_dreb',
#  'h_s3_reb',
#  'h_s3_ast',
#  'h_s3_stl',
#  'h_s3_blk',
#  'h_s3_to',
#  'h_s3_pf',
#  'h_s3_pts',
#  'h_s3_poss',
#  'h_s3_off_rate',
#  'h_s3_def_rate',
#  'h_s3_net_rate',
#  'h_s3_pace',
#  'h_s3_ast_pct',
#  'h_s3_ast_tov',
#  'h_s3_ast_ratio',
#  'h_s3_oreb_pct',
#  'h_s3_dreb_pct',
#  'h_s3_reb_pct',
#  'h_s3_tm_tov_pct',
#  'h_s3_usg_pct',
#  'h_s3_game_score',
#  'h_s3_plus_minus',
#  'a_pg_seconds',
#  'a_pg_fgm',
#  'a_pg_fga',
#  'a_pg_fg3m',
#  'a_pg_fg3a',
#  'a_pg_ftm',
#  'a_pg_fta',
#  'a_pg_oreb',
#  'a_pg_dreb',
#  'a_pg_reb',
#  'a_pg_ast',
#  'a_pg_stl',
#  'a_pg_blk',
#  'a_pg_to',
#  'a_pg_pf',
#  'a_pg_pts',
#  'a_pg_poss',
#  'a_pg_off_rate',
#  'a_pg_def_rate',
#  'a_pg_net_rate',
#  'a_pg_pace',
#  'a_pg_ast_pct',
#  'a_pg_ast_tov',
#  'a_pg_ast_ratio',
#  'a_pg_oreb_pct',
#  'a_pg_dreb_pct',
#  'a_pg_reb_pct',
#  'a_pg_tm_tov_pct',
#  'a_pg_usg_pct',
#  'a_pg_game_score',
#  'a_pg_plus_minus',
#  'a_sg_seconds',
#  'a_sg_fgm',
#  'a_sg_fga',
#  'a_sg_fg3m',
#  'a_sg_fg3a',
#  'a_sg_ftm',
#  'a_sg_fta',
#  'a_sg_oreb',
#  'a_sg_dreb',
#  'a_sg_reb',
#  'a_sg_ast',
#  'a_sg_stl',
#  'a_sg_blk',
#  'a_sg_to',
#  'a_sg_pf',
#  'a_sg_pts',
#  'a_sg_poss',
#  'a_sg_off_rate',
#  'a_sg_def_rate',
#  'a_sg_net_rate',
#  'a_sg_pace',
#  'a_sg_ast_pct',
#  'a_sg_ast_tov',
#  'a_sg_ast_ratio',
#  'a_sg_oreb_pct',
#  'a_sg_dreb_pct',
#  'a_sg_reb_pct',
#  'a_sg_tm_tov_pct',
#  'a_sg_usg_pct',
#  'a_sg_game_score',
#  'a_sg_plus_minus',
#  'a_sf_seconds',
#  'a_sf_fgm',
#  'a_sf_fga',
#  'a_sf_fg3m',
#  'a_sf_fg3a',
#  'a_sf_ftm',
#  'a_sf_fta',
#  'a_sf_oreb',
#  'a_sf_dreb',
#  'a_sf_reb',
#  'a_sf_ast',
#  'a_sf_stl',
#  'a_sf_blk',
#  'a_sf_to',
#  'a_sf_pf',
#  'a_sf_pts',
#  'a_sf_poss',
#  'a_sf_off_rate',
#  'a_sf_def_rate',
#  'a_sf_net_rate',
#  'a_sf_pace',
#  'a_sf_ast_pct',
#  'a_sf_ast_tov',
#  'a_sf_ast_ratio',
#  'a_sf_oreb_pct',
#  'a_sf_dreb_pct',
#  'a_sf_reb_pct',
#  'a_sf_tm_tov_pct',
#  'a_sf_usg_pct',
#  'a_sf_game_score',
#  'a_sf_plus_minus',
#  'a_pf_player_id',
#  'a_pf_name',
#  'a_pf_age_days',
#  'a_pf_height',
#  'a_pf_seconds',
#  'a_pf_fgm',
#  'a_pf_fga',
#  'a_pf_fg3m',
#  'a_pf_fg3a',
#  'a_pf_ftm',
#  'a_pf_fta',
#  'a_pf_oreb',
#  'a_pf_dreb',
#  'a_pf_reb',
#  'a_pf_ast',
#  'a_pf_stl',
#  'a_pf_blk',
#  'a_pf_to',
#  'a_pf_pf',
#  'a_pf_pts',
#  'a_pf_poss',
#  'a_pf_off_rate',
#  'a_pf_def_rate',
#  'a_pf_net_rate',
#  'a_pf_pace',
#  'a_pf_ast_pct',
#  'a_pf_ast_tov',
#  'a_pf_ast_ratio',
#  'a_pf_oreb_pct',
#  'a_pf_dreb_pct',
#  'a_pf_reb_pct',
#  'a_pf_tm_tov_pct',
#  'a_pf_usg_pct',
#  'a_pf_game_score',
#  'a_pf_plus_minus',
#  'a_c__seconds',
#  'a_c__fgm',
#  'a_c__fga',
#  'a_c__fg3m',
#  'a_c__fg3a',
#  'a_c__ftm',
#  'a_c__fta',
#  'a_c__oreb',
#  'a_c__dreb',
#  'a_c__reb',
#  'a_c__ast',
#  'a_c__stl',
#  'a_c__blk',
#  'a_c__to',
#  'a_c__pf',
#  'a_c__pts',
#  'a_c__poss',
#  'a_c__off_rate',
#  'a_c__def_rate',
#  'a_c__net_rate',
#  'a_c__pace',
#  'a_c__ast_pct',
#  'a_c__ast_tov',
#  'a_c__ast_ratio',
#  'a_c__oreb_pct',
#  'a_c__dreb_pct',
#  'a_c__reb_pct',
#  'a_c__tm_tov_pct',
#  'a_c__usg_pct',
#  'a_c__game_score',
#  'a_c__plus_minus',
#  'a_s1_seconds',
#  'a_s1_fgm',
#  'a_s1_fga',
#  'a_s1_fg3m',
#  'a_s1_fg3a',
#  'a_s1_ftm',
#  'a_s1_fta',
#  'a_s1_oreb',
#  'a_s1_dreb',
#  'a_s1_reb',
#  'a_s1_ast',
#  'a_s1_stl',
#  'a_s1_blk',
#  'a_s1_to',
#  'a_s1_pf',
#  'a_s1_pts',
#  'a_s1_poss',
#  'a_s1_off_rate',
#  'a_s1_def_rate',
#  'a_s1_net_rate',
#  'a_s1_pace',
#  'a_s1_ast_pct',
#  'a_s1_ast_tov',
#  'a_s1_ast_ratio',
#  'a_s1_oreb_pct',
#  'a_s1_dreb_pct',
#  'a_s1_reb_pct',
#  'a_s1_tm_tov_pct',
#  'a_s1_usg_pct',
#  'a_s1_game_score',
#  'a_s1_plus_minus',
#  'a_s2_seconds',
#  'a_s2_fgm',
#  'a_s2_fga',
#  'a_s2_fg3m',
#  'a_s2_fg3a',
#  'a_s2_ftm',
#  'a_s2_fta',
#  'a_s2_oreb',
#  'a_s2_dreb',
#  'a_s2_reb',
#  'a_s2_ast',
#  'a_s2_stl',
#  'a_s2_blk',
#  'a_s2_to',
#  'a_s2_pf',
#  'a_s2_pts',
#  'a_s2_poss',
#  'a_s2_off_rate',
#  'a_s2_def_rate',
#  'a_s2_net_rate',
#  'a_s2_pace',
#  'a_s2_ast_pct',
#  'a_s2_ast_tov',
#  'a_s2_ast_ratio',
#  'a_s2_oreb_pct',
#  'a_s2_dreb_pct',
#  'a_s2_reb_pct',
#  'a_s2_tm_tov_pct',
#  'a_s2_usg_pct',
#  'a_s2_game_score',
#  'a_s2_plus_minus',
#  'a_s3_seconds',
#  'a_s3_fgm',
#  'a_s3_fga',
#  'a_s3_fg3m',
#  'a_s3_fg3a',
#  'a_s3_ftm',
#  'a_s3_fta',
#  'a_s3_oreb',
#  'a_s3_dreb',
#  'a_s3_reb',
#  'a_s3_ast',
#  'a_s3_stl',
#  'a_s3_blk',
#  'a_s3_to',
#  'a_s3_pf',
#  'a_s3_pts',
#  'a_s3_poss',
#  'a_s3_off_rate',
#  'a_s3_def_rate',
#  'a_s3_net_rate',
#  'a_s3_pace',
#  'a_s3_ast_pct',
#  'a_s3_ast_tov',
#  'a_s3_ast_ratio',
#  'a_s3_oreb_pct',
#  'a_s3_dreb_pct',
#  'a_s3_reb_pct',
#  'a_s3_tm_tov_pct',
#  'a_s3_usg_pct',
#  'a_s3_game_score',
#  'a_s3_plus_minus',
#  'h_pg_ewm_height',
#  'h_sg_ewm_height',
#  'h_sf_ewm_height',
#  'h_pf_ewm_height',
#  'h_c__ewm_height',
#  'h_s1_ewm_height',
#  'h_s2_ewm_height',
#  'h_s3_ewm_height',
#  'a_pg_ewm_height',
#  'a_sg_ewm_height',
#  'a_sf_ewm_height',
#  'a_pf_ewm_height',
#  'a_c__ewm_height',
#  'a_s1_ewm_height',
#  'a_s2_ewm_height',
#  'a_s3_ewm_height']
