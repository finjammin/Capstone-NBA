# %%
import pandas as pd
import numpy as np

import psycopg2
import sqlalchemy

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set(font_scale=1.5)

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# DSN (data source name) format for database connections:  
# [protocol / database  name]://[username]:[password]@[hostname / ip]:[port]/[database name here]

# on your computer you are the user postgres (full administrative access)
db_user = 'postgres'
# if you need a password to access a database, put it here
db_password = ''
# on your computer, use localhost
db_host = 'localhost'
# the default port for postgres is 5432
db_port = 5432
# we want to creat a database with the following name
database = 'final_db'
#set up a connection to postgres without specifying the database
# conn_postgres = f'postgresql://{db_user}:{db_password}@{db_host}:{db_port}'

conn_str = f'postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{database}'
conn = psycopg2.connect(conn_str)

# connect using sqlalchemy
engine = sqlalchemy.engine.create_engine(conn_str)

# connect using sqlalchemy
connection = engine.connect()

# # commit
# connection.execute('commit')

# close connection
connection.close()

# open a new connection to the database that we created
database = 'final_db'
conn_str = f'postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{database}'
conn = psycopg2.connect(conn_str)

# connect using sqlalchemy
engine = sqlalchemy.engine.create_engine(conn_str)

# %%
query = """

SELECT c.nba_game_date, c.nba_season_id, e.br_location, c.nba_gm_type, e.br_outcome, c.nba_plus_minus home_plus_minus,  a.*, d.birthdate, d.nba_height, b.nba_e_off_rating, b.nba_off_rating, b.nba_e_def_rating, b.nba_def_rating,
b.nba_e_net_rating, b.nba_net_rating, b.nba_ast_pct, b.nba_ast_tov, b.nba_ast_ratio,
b.nba_oreb_pct, b.nba_dreb_pct, b.nba_reb_pct, b.nba_tm_tov_pct, b.nba_efg_pct,
b.nba_ts_pct, b.nba_usg_pct, b.nba_e_pace, b.nba_pace, b.nba_pace_per40, b.nba_poss, b.nba_pie, e.br_game_score
FROM nba_tra_box a
LEFT JOIN nba_adv_box b ON a.nba_player_id = b.nba_player_id AND a.nba_game_id = b.nba_game_id
LEFT JOIN (SELECT DISTINCT(nba_game_id), nba_game_date, nba_season_id, nba_plus_minus, nba_gm_type FROM nba_team_box WHERE nba_matchup LIKE '% vs.%') c
ON a.nba_game_id = c.nba_game_id
LEFT JOIN (SELECT nba_person_id, nba_height, to_char(CAST(nba_birthdate as date), 'YYYY-MM-DD') birthdate FROM nba_common_attr) d
ON a.nba_player_id = d.nba_person_id
LEFT JOIN (SELECT br_slug, br_team, br_opponent, br_date, br_game_score, br_outcome, br_location FROM brid_tra_box) e
ON (a.nba_player_id = e.br_slug AND to_char(CAST(c.nba_game_date as date), 'YYYY-MM-DD') = to_char(CAST(e.br_date as date), 'YYYY-MM-DD'))
ORDER BY c.nba_game_date

"""

data = pd.read_sql(query, con=conn)
display(data.head(10))
data.info()
# Out:
#   nba_game_date nba_season_id br_location nba_gm_type br_outcome  \
# 0    1999-11-02         21999        AWAY     Regular          W
# 1    1999-11-02         21999        HOME     Regular          L
# 2    1999-11-02         21999        HOME     Regular          L
# 3    1999-11-02         21999        AWAY     Regular          W
# 4    1999-11-02         21999        AWAY     Regular          W
# 5    1999-11-02         21999        HOME     Regular          W
# 6    1999-11-02         21999        HOME     Regular          W
# 7    1999-11-02         21999        None     Regular       None
# 8    1999-11-02         21999        AWAY     Regular          W
# 9    1999-11-02         21999        AWAY     Regular          W
#
#    home_plus_minus nba_game_id nba_team_id nba_team_abbreviation  \
# 0               -7    29900011  1610612747                   LAL
# 1              -13    29900006  1610612761                   TOR
# 2              -13    29900006  1610612761                   TOR
# 3              -20    29900013  1610612757                   POR
# 4               -7    29900002  1610612754                   IND
# 5                6    29900004  1610612748                   MIA
# 6               14    29900005  1610612766                   CHH
# 7               -7    29900002  1610612751                   NJN
# 8              -12    29900012  1610612760                   SEA
# 9               -5    29900008  1610612749                   MIL
#
#   nba_team_city  ... nba_tm_tov_pct nba_efg_pct nba_ts_pct nba_usg_pct  \
# 0   Los Angeles  ...           14.3       0.250      0.307       0.240
# 1       Toronto  ...            0.0       0.438      0.438       0.174
# 2       Toronto  ...           14.3       0.143      0.415       0.197
# 3      Portland  ...            7.7       0.875      0.875       0.114
# 4       Indiana  ...            0.0       0.286      0.342       0.225
# 5         Miami  ...           10.0       0.357      0.451       0.188
# 6     Charlotte  ...           10.0       0.409      0.478       0.257
# 7    New Jersey  ...            NaN         NaN        NaN       0.000
# 8       Seattle  ...            7.1       0.250      0.250       0.138
# 9     Milwaukee  ...            0.0       0.571      0.538       0.167
#
#    nba_e_pace  nba_pace  nba_pace_per40  nba_poss  nba_pie  br_game_score
# 0       92.61     89.30           74.42      21.0   -0.017            1.2
# 1       92.14     95.14           79.28      40.0    0.174            5.2
# 2       94.95     96.55           80.46      55.0    0.005            2.6
# 3       88.39     87.66           73.05      41.0    0.204           10.8
# 4      103.06    103.57           86.31      36.0   -0.053            0.9
# 5      100.90    104.30           86.91      82.0    0.124           12.4
# 6      104.18    103.43           86.19      90.0    0.153           15.8
# 7         NaN       NaN             NaN       0.0      NaN            NaN
# 8       98.79     98.92           82.44      75.0    0.067            4.6
# 9       81.73     81.86           68.22      39.0    0.117            7.7
#
# [10 rows x 58 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 662482 entries, 0 to 662481
# Data columns (total 58 columns):
# nba_game_date            662482 non-null object
# nba_season_id            662482 non-null object
# br_location              553928 non-null object
# nba_gm_type              662482 non-null object
# br_outcome               553928 non-null object
# home_plus_minus          662482 non-null int64
# nba_game_id              662482 non-null object
# nba_team_id              662482 non-null object
# nba_team_abbreviation    662482 non-null object
# nba_team_city            662482 non-null object
# nba_player_id            662482 non-null object
# nba_player_name          662482 non-null object
# nba_start_position       269542 non-null object
# nba_comment              107710 non-null object
# nba_min                  662482 non-null int64
# nba_fgm                  554771 non-null float64
# nba_fga                  554771 non-null float64
# nba_fg_pct               554771 non-null float64
# nba_fg3m                 554771 non-null float64
# nba_fg3a                 554771 non-null float64
# nba_fg3_pct              554771 non-null float64
# nba_ftm                  554771 non-null float64
# nba_fta                  554771 non-null float64
# nba_ft_pct               554771 non-null float64
# nba_oreb                 554771 non-null float64
# nba_dreb                 554771 non-null float64
# nba_reb                  554771 non-null float64
# nba_ast                  554771 non-null float64
# nba_stl                  554771 non-null float64
# nba_blk                  554771 non-null float64
# nba_to                   554771 non-null float64
# nba_pf                   554771 non-null float64
# nba_pts                  554771 non-null float64
# nba_plus_minus           554748 non-null float64
# birthdate                662482 non-null object
# nba_height               652840 non-null float64
# nba_e_off_rating         554748 non-null float64
# nba_off_rating           662459 non-null float64
# nba_e_def_rating         554748 non-null float64
# nba_def_rating           662459 non-null float64
# nba_e_net_rating         554748 non-null float64
# nba_net_rating           662459 non-null float64
# nba_ast_pct              554748 non-null float64
# nba_ast_tov              554748 non-null float64
# nba_ast_ratio            554748 non-null float64
# nba_oreb_pct             662459 non-null float64
# nba_dreb_pct             662459 non-null float64
# nba_reb_pct              662459 non-null float64
# nba_tm_tov_pct           554748 non-null float64
# nba_efg_pct              554748 non-null float64
# nba_ts_pct               554748 non-null float64
# nba_usg_pct              662459 non-null float64
# nba_e_pace               554748 non-null float64
# nba_pace                 554748 non-null float64
# nba_pace_per40           554748 non-null float64
# nba_poss                 662459 non-null float64
# nba_pie                  554748 non-null float64
# br_game_score            553928 non-null float64
# dtypes: float64(42), int64(2), object(14)
# memory usage: 293.2+ MB

# %%
dfs_players = data.groupby('nba_player_id')

# %%
def position_creator(unique_start_positions):
    if len(unique_start_positions)<3:
        if 'G' in unique_start_positions:
            return 'G'
        elif 'C' in unique_start_positions:
            return 'C'
        elif 'F' in unique_start_positions:
            return 'F'
    elif len(unique_start_positions)==3:
        if 'F' in unique_start_positions:
            if 'G' in unique_start_positions:
                return 'G/F'
            elif 'C' in unique_start_positions:
                return 'F/C'
    elif len(unique_start_positions)==1:
        return 'None'

# %%
test = dfs_players.get_group(data['nba_player_id'].unique()[209])
display(test)
print((test['nba_start_position'].unique()))
print((position_creator(test['nba_start_position'].unique())))
# Out:
#        nba_game_date nba_season_id br_location nba_gm_type br_outcome  \
# 209       1999-11-02         21999        HOME     Regular          W
# 722       1999-11-05         21999        AWAY     Regular          L
# 908       1999-11-06         21999        AWAY     Regular          L
# 1189      1999-11-08         21999        HOME     Regular          W
# 1910      1999-11-12         21999        HOME     Regular          L
# ...              ...           ...         ...         ...        ...
# 307980    2009-04-29         42008        AWAY    Playoffs          L
# 313831    2009-11-22         22009        AWAY     Regular          L
# 314057    2009-11-24         22009        None     Regular       None
# 314466    2009-11-27         22009        None     Regular       None
# 315011    2009-11-29         22009        None     Regular       None
#
#         home_plus_minus nba_game_id nba_team_id nba_team_abbreviation  \
# 209                   5    29900010  1610612743                   DEN
# 722                  12    29900035  1610612743                   DEN
# 908                  15    29900045  1610612743                   DEN
# 1189                 15    29900053  1610612743                   DEN
# 1910                -15    29900078  1610612743                   DEN
# ...                 ...         ...         ...                   ...
# 307980               21    40800155  1610612740                   NOH
# 313831               16    20900197  1610612760                   OKC
# 314057              -10    20900206  1610612760                   OKC
# 314466               18    20900228  1610612760                   OKC
# 315011               -9    20900244  1610612760                   OKC
#
#         nba_team_city  ... nba_tm_tov_pct nba_efg_pct nba_ts_pct nba_usg_pct  \
# 209            Denver  ...            0.0       0.333      0.515       0.222
# 722            Denver  ...            0.0       1.000      1.000       0.067
# 908            Denver  ...            0.0       0.000      0.000       0.077
# 1189           Denver  ...           12.5       0.400      0.554       0.108
# 1910           Denver  ...            0.0       0.333      0.387       0.182
# ...               ...  ...            ...         ...        ...         ...
# 307980    New Orleans  ...            0.0       0.000      0.000       0.167
# 313831  Oklahoma City  ...            0.0       1.000      1.064       0.083
# 314057  Oklahoma City  ...            NaN         NaN        NaN       0.000
# 314466  Oklahoma City  ...            NaN         NaN        NaN       0.000
# 315011  Oklahoma City  ...            NaN         NaN        NaN       0.000
#
#         nba_e_pace  nba_pace  nba_pace_per40  nba_poss  nba_pie  br_game_score
# 209          79.60     82.50           68.75      16.0    0.273            6.3
# 722          90.70     93.84           78.20      28.0    0.046            2.9
# 908          82.34     83.15           69.30      21.0   -0.093           -1.1
# 1189         94.90     95.01           79.18      50.0    0.088           11.0
# 1910         88.73     92.65           77.21      18.0    0.028            1.6
# ...            ...       ...             ...       ...      ...            ...
# 307980      126.96    132.24          110.20       5.0    0.000           -1.1
# 313831      107.18    103.29           86.08      17.0    0.184            4.9
# 314057         NaN       NaN             NaN       0.0      NaN            NaN
# 314466         NaN       NaN             NaN       0.0      NaN            NaN
# 315011         NaN       NaN             NaN       0.0      NaN            NaN
#
# [663 rows x 58 columns]
# [None 'F' 'C' 'G']
# None

# %%
test['nba_player_name'].unique()
# Out:
# array(['Ryan Bowen'], dtype=object)

# %%
data[(data['br_outcome'].isna())&(data[data['nba_min']>0])][['nba_game_date','nba_player_name', 'nba_min']]

# %%
starters = data[data['nba_start_position'].isna()==False]

# %%
fig, ax = plt.subplots(figsize=(20,10))
sns.distplot(data[data['br_outcome']=='W']['br_game_score'])
sns.distplot(data[data['br_outcome']=='L']['br_game_score'])
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
winners = data[data['br_outcome']=='W']
losers = data[data['br_outcome']=='L']
var = 'nba_plus_minus'

fig, ax = plt.subplots(figsize=(20,10))
plt.hist([winners[var],losers[var],data[var]], alpha=.5, bins=20)
# plt.hist(data[data['br_outcome']=='L']['nba_plus_minus'])
plt.legend(['Winners', 'Losers', 'ALL'])
plt.show()

# %%
for col in data.columns:
    if data[col].dtype==float or data[col].dtype==int:
        print('COLUMN :',col)
        fig, ax = plt.subplots(figsize=(20,10))
        plt.hist([winners[col],losers[col],data[col]], alpha=.5, bins=20)
# plt.hist(data[data['br_outcome']=='L']['nba_plus_minus'])
        plt.title('COLUMN {} distribution'.format(col))
        plt.legend(['Winners', 'Losers', 'ALL'])
        plt.show()
# Out:
# COLUMN : home_plus_minus
# COLUMN : nba_min
# COLUMN : nba_fgm
# COLUMN : nba_fga
# COLUMN : nba_fg_pct
# COLUMN : nba_fg3m
# COLUMN : nba_fg3a
# COLUMN : nba_fg3_pct
# COLUMN : nba_ftm
# COLUMN : nba_fta
# COLUMN : nba_ft_pct
# COLUMN : nba_oreb
# COLUMN : nba_dreb
# COLUMN : nba_reb
# COLUMN : nba_ast
# COLUMN : nba_stl
# COLUMN : nba_blk
# COLUMN : nba_to
# COLUMN : nba_pf
# COLUMN : nba_pts
# COLUMN : nba_plus_minus
# COLUMN : nba_height
# COLUMN : nba_e_off_rating
# COLUMN : nba_off_rating
# COLUMN : nba_e_def_rating
# COLUMN : nba_def_rating
# COLUMN : nba_e_net_rating
# COLUMN : nba_net_rating
# COLUMN : nba_ast_pct
# COLUMN : nba_ast_tov
# COLUMN : nba_ast_ratio
# COLUMN : nba_oreb_pct
# COLUMN : nba_dreb_pct
# COLUMN : nba_reb_pct
# COLUMN : nba_tm_tov_pct
# COLUMN : nba_efg_pct
# COLUMN : nba_ts_pct
# COLUMN : nba_usg_pct
# COLUMN : nba_e_pace
# COLUMN : nba_pace
# COLUMN : nba_pace_per40
# COLUMN : nba_poss
# COLUMN : nba_pie
# COLUMN : br_game_score

# %%
fig, ax = plt.subplots(figsize=(20,10))
sns.distplot(data[data['br_location']=='HOME']['nba_plus_minus'])
sns.distplot(data[data['br_location']=='AWAY']['nba_plus_minus'])
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
df_corr = data.corr()
fig, ax = plt.subplots(figsize=(24, 20))
# mask
mask = np.triu(np.ones_like(df_corr, dtype=np.bool))
# adjust mask and df
mask = mask[1:, :-1]
corr = df_corr.iloc[1:,:-1].copy()
# color map
cmap = sns.diverging_palette(200, 10, 50, n=9, as_cmap=True)
# plot heatmap
sns.heatmap(corr, mask=mask, cmap=cmap, vmin=-1, vmax=1)
# ticks
yticks = [i.upper() for i in corr.index]
xticks = [i.upper() for i in corr.columns]
plt.yticks(plt.yticks()[0], labels=yticks, rotation=0)
plt.xticks(plt.xticks()[0], labels=xticks)
# title
title = 'CORRELATION MATRIX\nNBA BOX SCORES\n'
plt.title(title, loc='left', fontsize=18)
plt.show()

# %%
players.get_group(data['nba_player_id'].unique()[200])['nba_start_position'].unique()
# Out:
# array(['G', None, 'F'], dtype=object)

# %%
# Out:
#       nba_game_date nba_season_id br_location nba_gm_type br_outcome  \
# 200      1999-11-02         21999        AWAY     Regular          L
# 334      1999-11-03         21999        HOME     Regular          W
# 660      1999-11-05         21999        HOME     Regular          L
# 1027     1999-11-06         21999        AWAY     Regular          W
# 1250     1999-11-08         21999        AWAY     Regular          W
# ...             ...           ...         ...         ...        ...
# 62690    2001-11-13         22001        HOME     Regular          W
# 62971    2001-11-15         22001        HOME     Regular          L
# 63376    2001-11-17         22001        AWAY     Regular          W
# 63600    2001-11-19         22001        HOME     Regular          W
# 63868    2001-11-21         22001        HOME     Regular          L
#
#        home_plus_minus nba_game_id nba_team_id nba_team_abbreviation  \
# 200                 14    29900005  1610612753                   ORL
# 334                  9    29900015  1610612753                   ORL
# 660                 -5    29900029  1610612753                   ORL
# 1027                -3    29900036  1610612753                   ORL
# 1250                -5    29900052  1610612753                   ORL
# ...                ...         ...         ...                   ...
# 62690                8    20100106  1610612743                   DEN
# 62971              -19    20100120  1610612743                   DEN
# 63376              -10    20100140  1610612743                   DEN
# 63600                3    20100144  1610612743                   DEN
# 63868              -21    20100161  1610612743                   DEN
#
#       nba_team_city  ... nba_tm_tov_pct nba_efg_pct nba_ts_pct nba_usg_pct  \
# 200         Orlando  ...           22.2       0.286      0.286       0.196
# 334         Orlando  ...           21.4       0.278      0.311       0.309
# 660         Orlando  ...           10.0       0.531      0.563       0.227
# 1027        Orlando  ...            7.1       0.625      0.658       0.150
# 1250        Orlando  ...            0.0       0.333      0.388       0.151
# ...             ...  ...            ...         ...        ...         ...
# 62690        Denver  ...            9.1       0.600      0.600       0.289
# 62971        Denver  ...            8.3       0.111      0.145       0.275
# 63376        Denver  ...           16.7       0.500      0.563       0.055
# 63600        Denver  ...            5.9       0.455      0.470       0.161
# 63868        Denver  ...           12.5       0.167      0.167       0.233
#
#        nba_e_pace  nba_pace  nba_pace_per40  nba_poss  nba_pie  br_game_score
# 200        103.08    103.03           85.86      42.0   -0.020           -0.5
# 334        111.83    110.51           92.09      64.0    0.026            2.6
# 660        105.69    103.59           86.32      72.0    0.142           13.2
# 1027       104.21    106.50           88.75      72.0    0.106           13.4
# 1250       111.99    109.61           91.34      69.0    0.124            8.0
# ...           ...       ...             ...       ...      ...            ...
# 62690       93.79     91.74           76.45      33.0    0.114            7.2
# 62971       93.86     91.50           76.25      33.0   -0.190           -2.8
# 63376       90.47     90.11           75.09      75.0    0.060            6.3
# 63600       87.80     87.38           72.82      72.0    0.066           11.5
# 63868       91.77     92.40           77.00      26.0   -0.042           -0.1
#
# [80 rows x 58 columns]

# %%
test['nba_start_position'].unique()
# Out:
# array(['G', None, 'F'], dtype=object)

# %%
data.to_csv('total_dataset.csv')
# Out:
#        nba_game_date nba_season_id br_location nba_gm_type br_outcome  \
# 3         1999-11-02         21999        None     Regular       None
# 7         1999-11-02         21999        None     Regular       None
# 9         1999-11-02         21999        None     Regular       None
# 20        1999-11-02         21999        None     Regular       None
# 59        1999-11-02         21999        None     Regular       None
# ...              ...           ...         ...         ...        ...
# 662454    2020-10-09         42019        None    Playoffs       None
# 662456    2020-10-11         42019        None    Playoffs       None
# 662466    2020-10-11         42019        None    Playoffs       None
# 662469    2020-10-11         42019        None    Playoffs       None
# 662479    2020-10-11         42019        None    Playoffs       None
#
#         home_plus_minus nba_game_id nba_team_id nba_team_abbreviation  \
# 3                   -20    29900013  1610612763                   VAN
# 7                   -13    29900006  1610612738                   BOS
# 9                     7    29900003  1610612737                   ATL
# 20                   -5    29900008  1610612745                   HOU
# 59                    5    29900010  1610612756                   PHX
# ...                 ...         ...         ...                   ...
# 662454               -3    41900405  1610612748                   MIA
# 662456              -13    41900406  1610612747                   LAL
# 662466              -13    41900406  1610612748                   MIA
# 662469              -13    41900406  1610612747                   LAL
# 662479              -13    41900406  1610612748                   MIA
#
#        nba_team_city  ... nba_tm_tov_pct nba_efg_pct nba_ts_pct nba_usg_pct  \
# 3          Vancouver  ...            NaN         NaN        NaN         0.0
# 7             Boston  ...            NaN         NaN        NaN         0.0
# 9            Atlanta  ...            NaN         NaN        NaN         0.0
# 20           Houston  ...            NaN         NaN        NaN         0.0
# 59           Phoenix  ...            NaN         NaN        NaN         0.0
# ...              ...  ...            ...         ...        ...         ...
# 662454         Miami  ...            NaN         NaN        NaN         0.0
# 662456   Los Angeles  ...            NaN         NaN        NaN         0.0
# 662466         Miami  ...            NaN         NaN        NaN         0.0
# 662469   Los Angeles  ...            NaN         NaN        NaN         0.0
# 662479         Miami  ...            NaN         NaN        NaN         0.0
#
#         nba_e_pace  nba_pace  nba_pace_per40  nba_poss  nba_pie  br_game_score
# 3              NaN       NaN             NaN       0.0      NaN            NaN
# 7              NaN       NaN             NaN       0.0      NaN            NaN
# 9              NaN       NaN             NaN       0.0      NaN            NaN
# 20             NaN       NaN             NaN       0.0      NaN            NaN
# 59             NaN       NaN             NaN       0.0      NaN            NaN
# ...            ...       ...             ...       ...      ...            ...
# 662454         NaN       NaN             NaN       0.0      NaN            NaN
# 662456         NaN       NaN             NaN       0.0      NaN            NaN
# 662466         NaN       NaN             NaN       0.0      NaN            NaN
# 662469         NaN       NaN             NaN       0.0      NaN            NaN
# 662479         NaN       NaN             NaN       0.0      NaN            NaN
#
# [108554 rows x 58 columns]
